# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # Imports

# %%
from web_crawler import WebCrawler
from content_processor import ContentProcessor
from analyze import Analyze
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # WebCrawler
#  - WebCrawler can be instantiated with a csv containing seed, num_pages and domain or with keyword arguments; there is also the option to thread or not
#      - Threading applies to the domain list, so it only makes sense to use with domain=''
#  - Each WebCrawler instance will immediately begin crawling and upon completion will ouput a list of urls and metadata
#      - Be aware that subsequent instantiations of WebCrawler override the data in the 'repository' folder

# %%
# wiki_crawler = WebCrawler('specification.csv')
# wiki_crawler = WebCrawler(seed='https://en.wikipedia.org/wiki/Main_Page', threaded=True, num_pages=5, domain='en.wikipedia.org')
wiki_crawler = WebCrawler(seed='https://en.wikipedia.org/wiki/Main_Page', num_pages=5, domain='en.wikipedia.org')
# Out:
# <table><tr><td>Live URL</td><td>File</td><td>Status</td><td># Links</td><td># Images</td></tr><tr><td><a href=https://en.wikipedia.org/wiki/Main_Page>https://en.wikipedia.org/wiki/Main_Page<td><a href=repository/1.html>https://en.wikipedia.org/wiki/Main_Page</a></td><td>200</td><td>340</td><td>21</td></tr><tr><td><a href=https://en.wikipedia.org/wiki/Ramsar_site>https://en.wikipedia.org/wiki/Ramsar_site<td><a href=repository/2.html>https://en.wikipedia.org/wiki/Ramsar_site</a></td><td>200</td><td>431</td><td>5</td></tr><tr><td><a href=https://en.wikipedia.org/wiki/Wikipedia:Community_portal>https://en.wikipedia.org/wiki/Wikipedia:Community_portal<td><a href=repository/3.html>https://en.wikipedia.org/wiki/Wikipedia:Community_portal</a></td><td>200</td><td>2334</td><td>29</td></tr><tr><td><a href=https://en.wikipedia.org/wiki/Julia_Yeomans>https://en.wikipedia.org/wiki/Julia_Yeomans<td><a href=repository/4.html>https://en.wikipedia.org/wiki/Julia_Yeomans</a></td><td>200</td><td>249</td><td>5</td></tr><tr><td><a href=https://en.wikipedia.org/wiki/Wikipedia:Introduction>https://en.wikipedia.org/wiki/Wikipedia:Introduction<td><a href=repository/5.html>https://en.wikipedia.org/wiki/Wikipedia:Introduction</a></td><td>200</td><td>184</td><td>8</td></tr><tr><td><a href=https://en.wikipedia.org/wiki/Portal:Current_events>https://en.wikipedia.org/wiki/Portal:Current_events<td><a href=repository/6.html>https://en.wikipedia.org/wiki/Portal:Current_events</a></td><td>200</td><td>1139</td><td>5</td></tr><tr><td><a href=https://en.wikipedia.org/wiki/Wikipedia:Village_pump>https://en.wikipedia.org/wiki/Wikipedia:Village_pump<td><a href=repository/7.html>https://en.wikipedia.org/wiki/Wikipedia:Village_pump</a></td><td>200</td><td>546</td><td>10</td></tr><tr><td><a href=https://en.wikipedia.org/wiki/Global_warming>https://en.wikipedia.org/wiki/Global_warming<td><a href=repository/8.html>https://en.wikipedia.org/wiki/Global_warming</a></td><td>200</td><td>2743</td><td>51</td></tr><tr><td><a href=https://en.wikipedia.org/wiki/Wikipedia:General_disclaimer>https://en.wikipedia.org/wiki/Wikipedia:General_disclaimer<td><a href=repository/9.html>https://en.wikipedia.org/wiki/Wikipedia:General_disclaimer</a></td><td>200</td><td>228</td><td>4</td></tr><tr><td><a href=https://en.wikipedia.org/wiki/Intergovernmental_Panel_on_Climate_Change>https://en.wikipedia.org/wiki/Intergovernmental_Panel_on_Climate_Change<td><a href=repository/10.html>https://en.wikipedia.org/wiki/Intergovernmental_Panel_on_Climate_Change</a></td><td>200</td><td>2137</td><td>22</td></tr><tr><td><a href=https://en.wikipedia.org/wiki/Nobel_Memorial_Prize_in_Economic_Sciences>https://en.wikipedia.org/wiki/Nobel_Memorial_Prize_in_Economic_Sciences<td><a href=repository/11.html>https://en.wikipedia.org/wiki/Nobel_Memorial_Prize_in_Economic_Sciences</a></td><td>200</td><td>743</td><td>7</td></tr><tr><td><a href=https://en.wikipedia.org/wiki/Titchmarsh_Nature_Reserve>https://en.wikipedia.org/wiki/Titchmarsh_Nature_Reserve<td><a href=repository/12.html>https://en.wikipedia.org/wiki/Titchmarsh_Nature_Reserve</a></td><td>200</td><td>248</td><td>5</td></tr><tr><td><a href=https://en.wikipedia.org/wiki/Church_of_Norway>https://en.wikipedia.org/wiki/Church_of_Norway<td><a href=repository/13.html>https://en.wikipedia.org/wiki/Church_of_Norway</a></td><td>200</td><td>735</td><td>14</td></tr><tr><td><a href=https://en.wikipedia.org/w/index.php>https://en.wikipedia.org/w/index.php<td><a href=repository/14.html>https://en.wikipedia.org/w/index.php</a></td><td>200</td><td>340</td><td>21</td></tr><tr><td><a href=https://en.wikipedia.org/wiki/Special_Report_on_Global_Warming_of_1.5_%C2%BAC>https://en.wikipedia.org/wiki/Special_Report_on_Global_Warming_of_1.5_%C2%BAC<td><a href=repository/15.html>https://en.wikipedia.org/wiki/Special_Report_on_Global_Warming_of_1.5_%C2%BAC</a></td><td>200</td><td>466</td><td>12</td></tr><tr><td><a href=https://en.wikipedia.org/wiki/English_language>https://en.wikipedia.org ...

# %% [markdown]
# # Content Processor
#  - A ContentProcessor instance will extract text from each html file and put it in the 'processed' folder

# %%
cp = ContentProcessor()
cp.process_repository()

# %% [markdown]
# # Analysis
#   - An Analyze instance will analyze the text data in the 'processed' folder
#   - the plot_graph method will plot the Zipf's Law for the data
#   - the plot_most_frequent method will plot a table for the first 100 most common words

# %%
analysis = Analyze()
print(f'N = {analysis.total_words}')
# Out:
# N = 45996

# %%
analysis.plot_graph('Wikipedia')

# %%
analysis.plot_most_frequent()
