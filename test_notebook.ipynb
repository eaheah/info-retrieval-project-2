# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
print( os.path.join('asdf', 'asdf'))
# Out:
# asdf/asdf

# %%
import numpy as np

# %%
A = np.array([[1,2], [3,4], [5,6]])
A = A.transpose()
print(A)
# Out:
# [[1 3 5]
#  [2 4 6]]

# %%
import warnings
warnings.filterwarnings('ignore')
from analyze import Analyze
a = Analyze()
a.process_text()
a.plot_graph('relativity')
a.plot_most_frequent()

# %%
from web_crawler import WebCrawler

# %%
lamyield = (x for x in range(15))
print(next(lamyield))
print(next(lamyield))
# Out:
# 0
# 1

# %%
import time
st = time.time()
crawler = WebCrawler('specification.csv')
print(time.time() - st)
# Out:
# <table><tr><td>Live URL</td><td>File</td><td>Status</td><td># Links</td><td># Images</td></tr><tr><td><a href=http://www.apple.com/mac>http://www.apple.com/mac<td><a href=repository/1.html>http://www.apple.com/mac/</a></td><td>200</td><td>164</td><td>0</td></tr><tr><td><a href=http://www.apple.com/choose-country-region>http://www.apple.com/choose-country-region<td><a href=repository/2.html>http://www.apple.com/choose-country-region/</a></td><td>200</td><td>212</td><td>0</td></tr><tr><td><a href=http://www.apple.com/us/shop/goto/imac/select>http://www.apple.com/us/shop/goto/imac/select<td><a href=repository/3.html>http://www.apple.com/us/shop/goto/imac/select</a></td><td>200</td><td>96</td><td>16</td></tr><tr><td><a href=http://www.apple.com/us/shop/goto/help>http://www.apple.com/us/shop/goto/help<td><a href=repository/4.html>http://www.apple.com/us/shop/goto/help</a></td><td>200</td><td>109</td><td>3</td></tr><tr><td><a href=http://www.apple.com/today/collection/behind-the-mac>http://www.apple.com/today/collection/behind-the-mac<td><a href=repository/5.html>http://www.apple.com/today/collection/behind-the-mac/</a></td><td>200</td><td>83</td><td>0</td></tr></table>
# 20.50948405265808

# %%
st = time.time()
crawler = WebCrawler(seed='https://en.wikipedia.org/wiki/Main_Page', num_pages=100, domain='en.wikipedia.org')
print(time.time() - st)
# Out:
# <table><tr><td>Live URL</td><td>File</td><td>Status</td><td># Links</td><td># Images</td></tr><tr><td><a href=https://en.wikipedia.org/wiki/Main_Page>https://en.wikipedia.org/wiki/Main_Page<td><a href=repository/1.html>https://en.wikipedia.org/wiki/Main_Page</a></td><td>200</td><td>313</td><td>20</td></tr><tr><td><a href=https://en.wikipedia.org/wiki/Wikipedia:Picture_of_the_day/October_2018>https://en.wikipedia.org/wiki/Wikipedia:Picture_of_the_day/October_2018<td><a href=repository/2.html>https://en.wikipedia.org/wiki/Wikipedia:Picture_of_the_day/October_2018</a></td><td>200</td><td>651</td><td>16</td></tr><tr><td><a href=https://en.wikipedia.org/wiki/Portal:Mathematics>https://en.wikipedia.org/wiki/Portal:Mathematics<td><a href=repository/3.html>https://en.wikipedia.org/wiki/Portal:Mathematics</a></td><td>200</td><td>601</td><td>52</td></tr><tr><td><a href=https://en.wikipedia.org/wiki/Help:Contents>https://en.wikipedia.org/wiki/Help:Contents<td><a href=repository/4.html>https://en.wikipedia.org/wiki/Help:Contents</a></td><td>200</td><td>491</td><td>17</td></tr><tr><td><a href=https://en.wikipedia.org/wiki/Wikipedia:General_disclaim
td></tr><tr><td><a href=https://en.wikipedia.org/wiki/Wikipedia:Picture_of_the_day/October_2018>https://en.wikipedia.org/wiki/Wikipedia:Picture_of_the_day/October_2018<td><a href=repository/2.html>https://en.wikipedia.org/wiki/Wikipedia:Picture_of_the_day/October_2018</a></td><td>200</td><td>651</td><td>16</td></tr><tr><td><a href=https://en.wikipedia.org/wiki/Portal:Mathematics>https://en.wikipedia.org/wiki/Portal:Mathematics<td><a href=repository/3.html>https://en.wikipedia.org/wiki/Portal:Mathematics</a></td><td>200</td><td>601</td><td>52</td></tr></table>
# 4.960438013076782

# %%
# Getting sitemaps as valid urls for reddit. TODO; also, getting 429, probably because of https://github.com/reddit-archive/reddit/wiki/API#rules
crawler = WebCrawler(seed='https://www.reddit.com/', num_pages=2, domain='')
# Out:
# get_kwarg_input took 9.5367431640625e-07
# validate_input took 3.2901763916015625e-05
# initialize_repo took 0.0022110939025878906
# request (in check for robot) took 1.0816540718078613
# check_for_robot took 2.0850613117218018
# https://www.reddit.com/
# find_links took 0.0017037391662597656
# process_url took 3.3037900924682617
# initialize_seed took 3.3038361072540283
# check_file_count took 1.1920928955078125e-06
# request (in check for robot) took 0.8443751335144043
# check_for_robot took 1.850830078125
# http://github.com/reddit/reddit/wiki/API
# find_links took 0.0266110897064209
# process_url took 3.6404190063476562
# display
# https://www.reddit.com/
# http://github.com/reddit/reddit/wiki/API
# <table><tr><td>Live URL</td><td>File</td><td>Status</td><td># Links</td><td># Images</td></tr><tr><td><a href=https://www.reddit.com>https://www.reddit.com<td><a href=repository/1.html>https://www.reddit.com/</a></td><td>429</td><td>1</td><td>0</td></tr><tr><td><a href=http://github.com/reddit/reddit/wiki/API>http://github.com/reddit/reddit/wiki/API<td><a href=repository/2.html>http://github.com/reddit/reddit/wiki/API</a></td><td>200</td><td>89</td><td>3</td></tr></table>
# display took 0.001979827880859375
# check_file_count took 0.0020301342010498047
# process_main_link_queue took 3.642557144165039

# %%
crawler = WebCrawler(seed='https://en.wikipedia.org/wiki/Main_Page', num_pages=2, domain='en.wikipedia.org')
# Out:
# <table><tr><td>Live URL</td><td>File</td><td>Status</td><td># Links</td><td># Images</td></tr><tr><td><a href=https://en.wikipedia.org/wiki/Main_Page>https://en.wikipedia.org/wiki/Main_Page<td><a href=repository/1.html>https://en.wikipedia.org/wiki/Main_Page</a></td><td>200</td><td>323</td><td>20</td></tr><tr><td><a href=https://en.wikipedia.org/wiki/Theropod>https://en.wikipedia.org/wiki/Theropod<td><a href=repository/2.html>https://en.wikipedia.org/wiki/Theropod</a></td><td>200</td><td>1051</td><td>44</td></tr></table>

# %%
from content_processor import ContentProcessor

# %%
cp = ContentProcessor()
cp.process_repository()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-60d7f06ec539> in <module>
# ----> 1 cp = ContentProcessor()
#       2 cp.process_repository()
#
# NameError: name 'ContentProcessor' is not defined
